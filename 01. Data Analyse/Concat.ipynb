# %%
import pandas as pd
import numpy as np

df_imdb_fr = pd.read_csv("export/df_imdb_fr.csv", on_bad_lines='skip')

df_imdb_fr.head()
# Out:
# <ipython-input-2-8f3e38721f11>:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_imdb_fr = pd.read_csv("export/df_imdb_fr.csv", on_bad_lines='skip')
#      titleId  ordering                             title region language  \
# 0  tt0000002         2            Le clown et ses chiens     FR       \N
# 1  tt0000003         8                    Pauvre Pierrot     FR       \N
# 2  tt0000004         2                       Un bon bock     FR       \N
# 3  tt0000010        17      La sortie de l'usine Lumière     FR       \N
# 4  tt0000012        18  L'arrivée d'un train à La Ciotat     FR       \N
#
#          types attributes isOriginalTitle
# 0  imdbDisplay         \N               0
# 1  imdbDisplay         \N               0
# 2  imdbDisplay         \N               0
# 3  alternative         \N               0
# 4  imdbDisplay         \N               0

# %%
df_tournage_films = pd.read_csv("export/df_tournage_films.csv", on_bad_lines='skip')

df_tournage_films.head()
# Out:
#                          titre                       réalisateur  \
# 0        TOUT S'EST BIEN PASSE                     Francois OZON
# 1  Une jeune fille qui va bien                Sandrine Kiberlain
# 2                  French Exit                     Azazel Jacobs
# 3               FIN DE MATINEE                 Hiroshi NISHATANI
# 4                  HORS NORMES  Eric Toledano et Olivier Nakache
#
#             producteur  postal       debut         fin   latitude  longitude  \
# 0  MANDARIN PRODUCTION   75013  2020-08-20  2020-08-21  48.835660   2.348315
# 1        CURIOSA FILMS   75004  2020-08-31  2020-09-01  48.854533   2.361694
# 2          Same Player   75012  2019-12-04  2019-12-04  48.850067   2.376519
# 3    COMME DES CINEMAS   75004  2018-11-05  2018-11-05  48.854112   2.354679
# 4      ADNP QUAD FILMS   75001  2018-11-05  2018-11-06  48.865744   2.327446
#
#      rive
# 0  gauche
# 1  droite
# 2  droite
# 3  droite
# 4  droite

# %%
df_productor = pd.read_csv("export/df_productor.csv", on_bad_lines='skip')

df_productor["idTitles"] = df_productor["knownForTitles"].str.split(',')
df_productor = df_productor.drop(columns=['knownForTitles', 'nconst', 'primaryProfession'])

df_productor.head(10)
# Out:
#          primaryName  birthYear  deathYear  \
# 0          Doris Day       1922       2019
# 1       Kirk Douglas       1916       2020
# 2            Gong Li       1965       3000
# 3     Henner Hofmann       1950       3000
# 4        John Cleese       1939       3000
# 5          Brad Pitt       1963       3000
# 6   Gillian Anderson       1968       3000
# 7    Pamela Anderson       1967       3000
# 8   Jennifer Aniston       1969       3000
# 9  Patricia Arquette       1968       3000
#
#                                        idTitles
# 0  [tt0049470, tt0045591, tt0048317, tt0053172]
# 1  [tt0054331, tt0043338, tt0080736, tt0049456]
# 2  [tt0473444, tt0101640, tt0397535, tt0430357]
# 3  [tt1825758, tt0113482, tt0097738, tt0097523]
# 4  [tt0071853, tt0095159, tt0085959, tt0063929]
# 5  [tt0114746, tt2935510, tt1210166, tt0356910]
# 6  [tt0106179, tt0455590, tt0442632, tt2294189]
# 7  [tt0426592, tt0306047, tt0893509, tt0115624]
# 8  [tt1723121, tt3442006, tt0279113, tt0108778]
# 9  [tt0412175, tt1065073, tt0108399, tt0145531]

# %%
df_productor = df_productor.explode('idTitles').reset_index().drop(columns=['index'])
df_productor.head()
# Out:
#     primaryName  birthYear  deathYear   idTitles
# 0     Doris Day       1922       2019  tt0049470
# 1     Doris Day       1922       2019  tt0045591
# 2     Doris Day       1922       2019  tt0048317
# 3     Doris Day       1922       2019  tt0053172
# 4  Kirk Douglas       1916       2020  tt0054331
